# %% [markdown]
# <a href="https://colab.research.google.com/github/GusthavoEduardoLima/lab_programming_class/blob/main/tratamento_execoces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
# !git config --global user.email "gusthavoeduardolima615@gmail.com"

# %%
# !git config --global user.name "Gusthavo"

# %%
print("Teste")

# %%
# !git init

# %%
# !git add .

# %%
# !git commit -m "Teste"

# %%
# Add your GitHub repository as a remote origin
# This tells Git where your remote repository is located
# !git remote add origin https://github.com/GusthavoEduardoLima/lab_programing_class.git

# You can verify that the remote was added by running:
# !git remote -v

# %%
# !git push --set-upstream origin master

# %%
import os
from google.colab import userdata

# Retrieve your GitHub token from Colab secrets
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

# First, ensure you have committed any changes.
# If you have new changes, run `!git add .` first, then commit.
# This will only create a commit if there are new changes.
# !git commit -m "Update from Colab"

# Your local branch is `master` as per the `git init` and commit messages.
# We will explicitly push the local `master` branch to the remote `mainb` branch.
# The `-u` flag sets the upstream, so future `git push` commands will know where to go.
# We include the GITHUB_TOKEN directly in the URL for authentication.
# !git push -u https://oauth2:$GITHUB_TOKEN@github.com/GusthavoEduardoLima/lab_programing_class.git master:mainb

# %% [markdown]
# ### Testando o Push para o GitHub

# %%
# Crie um arquivo de texto simples para testar
with open('test_file.txt', 'w') as f:
    f.write('Este é um arquivo de teste criado no Google Colab.\n')
    f.write('Ele deve aparecer no seu repositório GitHub.')
print('Arquivo test_file.txt criado.')

# %%
# 1. Adicione o novo arquivo ao staging area
# !git add test_file.txt

# 2. Commite a alteração
# !git commit -m "Add test_file.txt from Colab"

# 3. Empurre as alterações para o GitHub (usando a configuração que já fizemos)
# Se for a primeira vez que você está empurrando para um branch específico, pode ser necessário:
# !git push -u origin master:mainb (se o seu branch local for master e o remoto for mainb)
# Como já configuramos o upstream, apenas 'git push' deve funcionar.
# !git push

# %% [markdown]
# Após executar as células acima, verifique seu repositório GitHub (na branch `mainb` ou a que você configurou) para confirmar a presença do `test_file.txt`.
